# %% [markdown]
# <img align="right" width="50" height="50" src="https://avatars3.githubusercontent.com/u/2339114">
# <div style="text-align: left">Demo and showcase for Deep Impact AG, March 5 2019</div>
#
# # Extractive Text Summarization with Natural Language Processing
# <div style="text-align: right">Muriz Serifovic, 2019</div>

# %% [markdown]
# <p align="center">
#   <img src="https://i.imgur.com/KdBhz4c.png" alt="sharead"></img>
# </p>

# %% [markdown]
# <div style="text-align: right">Notebook online available under https://small.cat/pie</div>

# %% [markdown]
# # Introduction

# %% [markdown]
# Staying relevant in the ever changing technology landscape can be a challenge. At work, we are expected to keep abreast of new computer technologies, web design feels like a constant game of catch up and quitting the race for only a few months months will result in your skill set becoming obsolete.
#
# In short, we can see how knowledge gradually becomes its own unique and important form of currency at a fundamental level. Common resources for developers to brush up their skills include books, podcasts, blog posts, trending GitHub repos, and YouTube videos.
#
# With hundreds of tech talks shared daily, YouTube won in recent years popularity amongst developers - being more commonly their first choice to inform themselves about current technologies. Unfortunately, more often than not these type of videos challenge us to allocate a great chunk of time from our daily life. Expected video lenght range from 20 minutes up to 3 hours, with a busy working schedule we simply put don't have time to watch YouTube videos.
#
# In a recent thread, a Hacker News user wrote:
#
# >*Time management, to me, is a more powerful “skill up” than anything that could keep your GitHub green. When you know you have limited hours in the day and you have hard time commitments, you have no choice but to learn and work efficiently.*
#
# Browsing myself Hacker News for nearly six years, one topic wich regularly shows up is **staying up to date** (Figure 1). Users indicate that they have no time for almost anything besides their day-to-day job.
# With methods known from natural language processing, is it possible to densify the content from a YouTube video into one comprehensible PDF file?

# %% [markdown]
# <p align="center">
#   <img src="https://i.imgur.com/T4ZaB1N.png" alt="hackernews" width="70%"></img>
# </p>
# <center>Figure 1: Recent threads on Hacker News</center>

# %% [markdown]
# # Objective
# YouTube videos provide us with auto-generated subtitles. **sharead.app** aims to develop a model to extract useful bits of knowledge from subtitles and provide the user with a PDF file containing the summary.

# %% [markdown]
# # Scraping the data
#
# YouTubes captions are stored in a XML tree, which can be easily scraped.

# %%
import re
from html import parser, unescape
from urllib.request import urlopen
from xml.etree import ElementTree

import requests
from bs4 import BeautifulSoup


class YouTubeSubtitles:
    class CouldNotFetchSubtitles(Exception):
        """Raises an exception if subtitles could not be found."""

        def __init__(self, youtube_id: str):
            Exception.__init__(
                self,
                "Could not fetch the appropiate subtitles for {url}".format(
                    url=_SubtitleFetcher.BASE_URL.format(
                        youtube_id=youtube_id)))
            self.youtube_id = youtube_id

    @staticmethod
    def get_subtitle(youtube_id: str) -> list:
        """Retrieves the subtitle for the video."""
        try:
            youtube_id = _LinkParser(youtube_id).parse_url()
            return _SubtitleFetcher(youtube_id).parse()
        except Exception:
            raise YouTubeSubtitles.CouldNotFetchSubtitles(youtube_id)


class WebsiteText:
    @staticmethod
    def get_text(url: str) -> tuple:
        """Extracts all the paragraph text from an arbitrary webpage."""

        site = urlopen(url)
        soup = BeautifulSoup(site, "lxml")
        text = ' '.join(map(lambda p: p.text, soup.find_all('p')))
        return soup.title.text, text


class _LinkParser:
    """Extracts unique video id from youtube link."""

    def __init__(self, youtube_link: str):
        self.youtube_link = youtube_link

    def parse_url(self) -> str:
        if 'watch?v' in self.youtube_link:
            youtube_id = re.findall(r'^[^=]+=([^&]+)', self.youtube_link)
        elif 'youtu.be/' in self.youtube_link:
            youtube_id = re.findall(r'youtu\.be/([^&]+)', self.youtube_link)
        else:
            raise YouTubeSubtitles.CouldNotFetchSubtitles(self.youtube_link)
        return youtube_id[0]


class _SubtitleFetcher:
    BASE_URL = "https://www.youtube.com/watch?v={youtube_id}"
    YOUTUBE_API = "https://www.youtube.com/api/{api_url}"
    REGEX = re.compile(r'<[^>]*>', re.IGNORECASE)

    def __init__(self, youtube_id: str):
        self.youtube_id = youtube_id

    def fetch(self) -> str:
        website = requests.get(
            self.BASE_URL.format(youtube_id=self.youtube_id)).text
        timedtext_xml = website.find('timedtext')
        url = self.YOUTUBE_API.format(
            api_url=website[timedtext_xml:timedtext_xml +
                            website[timedtext_xml:].find('"')].replace(
                                '\\u0026', '&').replace('\\', ''))
        return requests.get(url).text

    def parse(self) -> list:
        data = self.fetch()
        return [{
            'text': re.sub(self.REGEX, '', unescape(xml_element.text)),
            'start': float(xml_element.attrib['start']),
        } for xml_element in ElementTree.fromstring(data)]

# %% [markdown]
# # Concrete example

# %% [markdown]
# Let's take as an example this informative video about artificial intelligence.
# The video is over 36 minutes long. Can it be summarized?
#
# video url: https://www.youtube.com/watch?v=jeq-nfpDX4I
#
# <p align="center">
#   <img src="https://i.imgur.com/SaYrLjb.png" alt="techtalk" width="100%"></img>
# </p>

# %% [markdown]
# Scraping the subtitles is the first step for sharead.app

# %%
from pprint import pprint
xml_struct = YouTubeSubtitles.get_subtitle(
    "https://www.youtube.com/watch?v=jeq-nfpDX4I")
pprint(xml_struct)
talk_title = "Christian Fehrlin, CEO Deep Impact AG | KMU SWISS Podium 2018 | «Generation next»"
raw_text = ' '.join([i['text'] for i in xml_struct])
# Out:
# [{'start': 4.22, 'text': 'wir starten jetzt gleich mit dem ersten'},
#  {'start': 6.099, 'text': 'referenten das ist christian verleihen'},
#  {'start': 9.469, 'text': 'er arbeitet seit 1996 in der digitalen'},
#  {'start': 13.49, 'text': 'welt und realisiert seit der digitale'},
#  {'start': 16.55, 'text': 'und dies ruft iwe projekte mit seiner'},
#  {'start': 19.789, 'text': 'firma deep impact treibt unter anderem'},
#  {'start': 22.55, 'text': 'die entwicklung von e mail und casey'},
#  {'start': 25.48, 'text': 'lösungen zur online voran zur online'},
#  {'start': 28.88, 'text': 'identifikation von kunden basierend auf'},
#  {'start': 31.429, 'text': 'künstlicher intelligenz'},
#  {'start': 33.41, 'text': 'ich nehme an sie wissen was e mail und'},
#  {'start': 36.079, 'text': 'crm lösungen sind oder nein ich auch'},
#  {'start': 39.59, 'text': 'nicht aber christian verleihen herzlich'},
#  {'start': 41.66, 'text': 'willkommen'},
#  {'start': 46.93, 'text': 'hallo mr'},
#  {'start': 52.82, 'text': 'das klingt sehr nach einer'},
#  {'start': 54.05, 'text': 'hip-hop-gruppe als nach lösungen ja das'},
#  {'start': 56.78, 'text': 'hört sich ziemlich cool orden ist aber'},
#  {'start': 59.24, 'text': 'was ziemlich trockene cm ist das anime'},
#  {'start': 63.43, 'text': 'mondry gesetz also der skate 3'},
#  {'start': 66.369, 'text': 'freigesetzt und das geldwäschereigesetz'},
#  {'start': 69.17, 'text': 'also mit dem dürfen firmen business'},
#  {'start': 72.26, 'text': 'machen dass sie nicht gegen das'},
#  {'start': 73.79, 'text': 'geldwäschereigesetz verstoßen und casey'},
#  {'start': 77.0, 'text': 'ist nur kosten und das ist in der'},
#  {'start': 79.13, 'text': 'finanzindustrie wichtig wenn er auf sich'},
#  {'start': 82.22, 'text': 'um boden und mit wenn du auf dich'},
#  {'start': 83.84, 'text': 'business machen nein ich muss die leute'},
#  {'start': 85.7, 'text': 'identifizieren mit denen ich business'},
#  {'start': 87.95, 'text': 'mache ich brauche pross kopien sie'},
#  {'start': 90.11, 'text': 'kennen das wenn sie irgendwann bank'},
#  {'start': 91.46, 'text': 'account eröffnen'},
#  {'start': 92.57, 'text': 'und wir brauchen ein background checks'},
#  {'start': 96.049, 'text': 'weil wenn jemand auf sanktionslisten'},
#  {'start': 97.88, 'text': 'steht sollten sie den auch nicht drohen'},
#  {'start': 99.56, 'text': 'worden und business machen dort wo den'},
#  {'start': 101.51, 'text': 'reputationsverlust und hohe bußen also'},
#  {'start': 105.38, 'text': 'die ig in der niederländer gerade 700'},
#  {'start': 108.74, 'text': 'millionen bezahlt weil sie die falschen'},
#  {'start': 110.81, 'text': 'leute angeboten haben sie sprechen aber'},
#  {'start': 116.299, 'text': 'jetzt nicht über die lösungen sondern'},
#  {'start': 117.83, 'text': 'sie spielen über artificial intelligence'},
#  {'start': 121.39, 'text': 'und wie sie unser leben verändert viel'},
#  {'start': 124.49, 'text': 'spaß so viel herzlichen dank'},
#  {'start': 130.79, 'text': 'künstlicher intelligenz ist in aller'},
#  {'start': 133.08, 'text': 'munde'},
#  {'start': 133.769, 'text': 'und es ist auch ein buzzword geworden'},
#  {'start': 136.44, 'text': 'jeder schmückt sich fast mit dem begriff'},
#  {'start': 140.01, 'text': 'ich würde aber gerne kurz zeigen'},
#  {'start': 143.269, 'text': 'widerstand heute ist und was überhaupt'},
#  {'start': 146.129, 'text': 'schon möglich ist was macht ihn packt'},
#  {'start': 149.519, 'text': 'grundsätzlich wir bieten firmen an ihre'},
#  {'start': 155.18, 'text': 'innovationsprojekte auszulagern ihre'},
#  {'start': 157.68, 'text': 'digitalen und wir realisieren die weil'},
#  {'start': 160.769, 'text': 'wir das effizient und auch schnell'},
#  {'start': 163.37, 'text': 'können und in diesem bereich forschen'},
#  {'start': 166.349, 'text': 'wir auch an orte fischl intelligence'},
#  {'start': 168.66, 'text': 'dass wir uns ist das kein baus wird für'},
#  {'start': 170.97, 'text': 'uns ist das tägliche brot und die sind'},
#  {'start': 173.97, 'text': 'auch nicht so schlecht was im'},
#  {'start': 175.26, 'text': 'internationalen vergleich liegen wir'},
#  {'start': 178.23, 'text': 'knapp hinter google die absolute'},
#  {'start': 180.599, 'text': 'marktführer sind und mit knapp meine ich'},
#  {'start': 183.75, 'text': '0,2 prozent was wirklich ganz wenig ist'},
#  {'start': 187.26, 'text': 'und das sind wir natürlich auch stolz'},
#  {'start': 189.049, 'text': 'aber fangen wir sagen dass wir kommen in'},
#  {'start': 192.36, 'text': 'der wunderbaren welt der künstlichen'},
#  {'start': 195.329, 'text': 'intelligenz'},
#  {'start': 209.36, 'text': '[Musik]'},
#  {'start': 214.66, 'text': 'er wolle dem 23'},
#  {'start': 225.48, 'text': 'jetzt ist von prozessen der 101 basteln'},
#  {'start': 235.21, 'text': 'die kinder erste casting moschee ist'},
#  {'start': 238.48, 'text': 'details'},
#  {'start': 263.56, 'text': 'works'},
#  {'start': 269.78, 'text': '[Musik]'},
#  {'start': 280.18, 'text': 'der planet trade invest freude kann'},
#  {'start': 284.27, 'text': 'ernst primosch denken'},
#  {'start': 326.21, 'text': '[Applaus]'},
#  {'start': 365.929, 'text': 'ich kann euch beruhigen das ist ein'},
#  {'start': 368.639, 'text': 'ausblick in die zukunft das gibt es noch'},
#  {'start': 371.459, 'text': 'nicht dass das ist gestellt der film'},
#  {'start': 374.219, 'text': 'geht auch noch etwas weiter aber es ist'},
#  {'start': 377.369, 'text': 'durchaus interessant vor vier oder fünf'},
#  {'start': 380.669, 'text': 'tagen hat der papa das ist vom'},
#  {'start': 384.419, 'text': 'amerikanischen militär bekannt gegeben'},
#  {'start': 387.719, 'text': 'dass sie zwei milliarden investieren in'},
#  {'start': 390.749, 'text': 'die künstliche intelligenz in autonome'},
#  {'start': 394.519, 'text': 'waffensysteme die sich selber besser in'},
#  {'start': 397.769, 'text': 'schuss wie selber besser entscheidungen'},
#  {'start': 400.049, 'text': 'treffen können'},
#  {'start': 401.309, 'text': 'da haben wir glück dass wir zu den gut'},
#  {'start': 404.039, 'text': 'geist gehören und beglückt aus amerika'},
#  {'start': 407.039, 'text': 'eine sehr stabile demokratie ist da kann'},
#  {'start': 410.639, 'text': 'nichts schiefgehen wenn sie jetzt aber'},
#  {'start': 417.709, 'text': 'weitergehen was ist denn künstliche'},
#  {'start': 419.629, 'text': 'intelligenz überhaupt das ist das ist'},
#  {'start': 423.209, 'text': 'relativ schwer zu erklären'},
#  {'start': 425.759, 'text': 'es ist sicher ein teilgebiet der'},
#  {'start': 427.559, 'text': 'informatik und es versucht die'},
#  {'start': 430.529, 'text': 'intelligentes verhalten zu'},
#  {'start': 432.799, 'text': 'automatisieren mobile wir schon ein'},
#  {'start': 435.179, 'text': 'problem haben zu definieren was ist denn'},
#  {'start': 437.489, 'text': 'überhaupt intelligentes verhalten und'},
#  {'start': 439.739, 'text': 'das ist intelligenz generell das wird'},
#  {'start': 443.699, 'text': 'auch philosophisch noch diskutiert ich'},
#  {'start': 446.189, 'text': 'weiß dass mal so stehen aber was wir'},
#  {'start': 448.499, 'text': 'haben'},
#  {'start': 449.249, 'text': 'wir haben eine schleichende integration'},
#  {'start': 451.919, 'text': 'von künstlichen intelligenzen und die'},
#  {'start': 454.079, 'text': 'nutzen sie auch täglich wenn sie vorher'},
#  {'start': 456.869, 'text': 'wahrscheinlich dass empörte heute'},
#  {'start': 459.089, 'text': 'entscheidet die maschine wenn sie da'},
#  {'start': 461.539, 'text': 'liquidieren soll dann haben sie heute'},
#  {'start': 464.639, 'text': 'eigentlich schon viele entscheidungen'},
#  {'start': 466.8, 'text': 'von maschinen die sie gar nicht so'},
#  {'start': 468.389, 'text': 'mitkriege'},
#  {'start': 469.15, 'text': 'also wenn sie google fragen dann wird'},
#  {'start': 472.6, 'text': 'die maschine entscheiden welche'},
#  {'start': 474.57, 'text': 'suchresultate ihnen vorgelegt werden'},
#  {'start': 477.7, 'text': 'aufgrund von ihrem surfverhalten wir'},
#  {'start': 480.34, 'text': 'haben google maps dass ihnen sagt was'},
#  {'start': 483.61, 'text': 'durchgeht respektive den weg zeigt und'},
#  {'start': 487.03, 'text': 'wie haben sie ihre oder alex und diese'},
#  {'start': 488.98, 'text': 'assistenten die sind die sagen ihnen'},
#  {'start': 491.23, 'text': 'eigentlich was sie hören wollen und das'},
#  {'start': 495.07, 'text': 'merkt man gar nicht so recht aber das'},
#  {'start': 497.02, 'text': 'ist alles künstliche intelligenz und die'},
#  {'start': 500.08, 'text': 'künstliche intelligenz ist alles eine'},
#  {'start': 501.91, 'text': 'frage der rechenleistung und des'},
#  {'start': 503.53, 'text': 'speicherplatzes'},
#  {'start': 504.55, 'text': 'das hört sich jetzt auch noch nicht so'},
#  {'start': 506.35, 'text': 'gefährlich und das ist ja auch das ist'},
#  {'start': 509.14, 'text': 'das kommt uns auch zugute computer'},
#  {'start': 511.24, 'text': 'werden schnelle rezepte und es gibt ja'},
#  {'start': 515.41, 'text': 'auch diese mosler wir verdoppeln die'},
#  {'start': 518.37, 'text': 'rechenleistung alle zwei jahre und das'},
#  {'start': 521.59, 'text': 'ist nach wie vor so wir sind sogar bei'},
#  {'start': 524.59, 'text': '18 monaten im schnitt und das ist so ein'},
#  {'start': 528.31, 'text': 'chip der verdoppelt also seine'},
#  {'start': 530.35, 'text': 'rechenleistung sie alle kennen das mit'},
#  {'start': 532.87, 'text': 'dem reiskorn auf dem schachbrett wenn'},
#  {'start': 535.0, 'text': 'man das so machen würde kriegt er dem'},
#  {'start': 537.67, 'text': 'bürger auf der welt 28 tonnen reis nach'},
#  {'start': 541.9, 'text': 'hause geliefert weil diese exponentielle'},
#  {'start': 545.14, 'text': 'kurve geht hat extrem schnell hoch und'},
#  {'start': 548.23, 'text': 'da haben wir unser hirn entgegen zu'},
#  {'start': 551.05, 'text': 'setzen das ist größer als ein job ist'},
#  {'start': 553.21, 'text': 'biologisch im schädel limitiert und die'},
#  {'start': 557.11, 'text': 'größe des computer hier uns eigentlich'},
#  {'start': 559.09, 'text': 'nicht'},
#  {'start': 559.77, 'text': 'es ist alles eine frage der zeit bis die'},
#  {'start': 563.82, 'text': 'bei uns überflügelt in bezug auf'},
#  {'start': 567.22, 'text': 'rechenleistung und ich habe da eine'},
#  {'start': 570.15, 'text': 'grafik mitgebracht die stimmt und sicher'},
#  {'start': 573.37, 'text': 'alle sehr positiv und froh wenn ich da'},
#  {'start': 576.79, 'text': 'schaue dann sind das 2002 sind etwa die'},
#  {'start': 583.11, 'text': 'rechenleistungen der chips auf einer'},
#  {'start': 585.79, 'text': 'maus so die rechenleistung ist ne maus'},
#  {'start': 589.06, 'text': 'das ist jetzt noch nicht so gefährlich'},
#  {'start': 591.63, 'text': 'zu 2022 wird ein chip etwa die'},
#  {'start': 596.92, 'text': 'rechenleistung von einem menschlichen'},
#  {'start': 598.54, 'text': 'hirn haben'},
#  {'start': 600.31, 'text': 'und es wird nicht nur einen chip geben'},
#  {'start': 602.38, 'text': 'also der ist die auch multipliziert und'},
#  {'start': 605.26, 'text': 'wo es dann ganz spannend wir zur 2045'},
#  {'start': 610.42, 'text': 'rechne man damit dass ein schiebt die'},
#  {'start': 612.22, 'text': 'rechenleistung der gesamten menschheit'},
#  {'start': 614.8, 'text': 'habe und da gibt es dann auch wieder'},
#  {'start': 617.32, 'text': 'mehrere jeeps davon also ja wir sind'},
#  {'start': 623.56, 'text': 'dann doch in guten händen aufgehoben und'},
#  {'start': 626.38, 'text': 'diese exposition alec uwe die sieht man'},
#  {'start': 628.42, 'text': 'eigentlich überall'},
#  {'start': 629.589, 'text': 'also wenn man jetzt aber auch schaut'},
#  {'start': 632.04, 'text': 'dort neun 1500 vor christus hat man das'},
#  {'start': 635.98, 'text': 'rad erfunden und irgendwann neuesten'},
#  {'start': 638.5, 'text': 'einem in den sinn gekommen'},
#  {'start': 640.11, 'text': '3500 vor christus also irgendwie 6000'},
#  {'start': 643.15, 'text': 'jahre später man könnte ja da mal lachen'},
#  {'start': 645.07, 'text': 'wagen hinhängen und nochmals 1000 1000'},
#  {'start': 649.23, 'text': '1500 jahre später hat man da noch pferde'},
#  {'start': 653.71, 'text': 'hingehängt dass er das hat sehr lange'},
#  {'start': 655.69, 'text': 'gedauert und heute stehen wir hier noch'},
#  {'start': 658.36, 'text': 'dass die menschen und heute und die'},
#  {'start': 660.46, 'text': 'heute sprechen wir von autonomen fahren'},
#  {'start': 663.43, 'text': 'auch dank künstlicher intelligenz so wo'},
#  {'start': 666.43, 'text': 'sind die heute im einsatz und was ist'},
#  {'start': 669.61, 'text': 'der stand es gibt ja auch durchaus'},
#  {'start': 671.76, 'text': 'positive dinge die mit de eingelöst'},
#  {'start': 675.19, 'text': 'werden können und das ist ein bisschen'},
#  {'start': 678.4, 'text': 'das problem auf der einen seite haben'},
#  {'start': 680.589, 'text': 'wir diese dunkle zukunft können sich'},
#  {'start': 683.14, 'text': 'kontrollieren'},
#  {'start': 684.4, 'text': 'die maschine wird entscheidungen für uns'},
#  {'start': 686.71, 'text': 'zu treffen und auf der anderen seite'},
#  {'start': 688.63, 'text': 'haben wir auch diese opportunities die'},
#  {'start': 692.08, 'text': 'die nächste generation profitieren kann'},
#  {'start': 695.5, 'text': 'davon so jetzt eigentlich fängt alles an'},
#  {'start': 697.96, 'text': 'mit intelligenten assistenten und das'},
#  {'start': 702.339, 'text': 'ist kein fake dass das das gibt es auch'},
#  {'start': 705.48, 'text': 'das ist eine demo die werden das auch'},
#  {'start': 709.57, 'text': 'ziemlich bald ausrollen'},
#  {'start': 711.81, 'text': 'das auto fährt völlig autonom ist kann'},
#  {'start': 715.48, 'text': 'an kreuzungen'},
#  {'start': 718.06, 'text': 'lichtsignale es erkennt de facto als und'},
#  {'start': 721.63, 'text': 'jetzt kommt meine lieblingsszene man'},
#  {'start': 725.23, 'text': 'kann aussteigen und dass er versucht'},
#  {'start': 728.02, 'text': 'sich dann ein parkplatz'},
#  {'start': 734.7, 'text': 'und das ist schon cool also das wird uns'},
#  {'start': 737.7, 'text': 'einiges erleichtern und das wird auch'},
#  {'start': 739.8, 'text': 'die unfallquote deutlich senken auch'},
#  {'start': 743.49, 'text': 'wenn wir da und geschichten wieder hören'},
#  {'start': 746.16, 'text': 'dass da ein autonomes fahrzeuge gecrasht'},
#  {'start': 748.98, 'text': 'ist sie sind heute schon viel viel viel'},
#  {'start': 751.65, 'text': 'sicherer'},
#  {'start': 753.74, 'text': 'ein tesla macht alle 130 millionen'},
#  {'start': 758.52, 'text': 'meilen ein crash an um alle autofahrer'},
#  {'start': 760.89, 'text': 'rolle 95 millionen'},
#  {'start': 764.72, 'text': 'dann ist natürlich wieder die frage des'},
#  {'start': 767.64, 'text': 'rub tief wie organisieren wir uns auch'},
#  {'start': 769.95, 'text': 'die gesellschaft wenn die künstlichen'},
#  {'start': 772.11, 'text': 'intelligenzen da unsere jobs wegnehmen'},
#  {'start': 774.57, 'text': '[Musik]'},
#  {'start': 775.77, 'text': 'man denkt ihr ist es soweit dass wir'},
#  {'start': 778.83, 'text': 'selbst fahrende taxis offiziell auf den'},
#  {'start': 781.77, 'text': 'straßen haben fünf jahre zehn jahre 20'},
#  {'start': 786.75, 'text': 'jahre also sie ist heute die namen es'},
#  {'start': 791.73, 'text': 'ist heute in amerika und so dass renault'},
#  {'start': 795.6, 'text': 'ist eine google tochter die hat'},
#  {'start': 797.7, 'text': 'angefangen in arizona im selbst fahrende'},
#  {'start': 801.0, 'text': 'taxi praxis zu betreiben und das ist'},
#  {'start': 804.93, 'text': 'auch cool und die selbst fahrenden auto'},
#  {'start': 807.54, 'text': 'hätten ja auch irgendwo vorteile'},
#  {'start': 810.23, 'text': 'man müsste dann auch wissen wie die'},
#  {'start': 812.34, 'text': 'politik auf die promillegrenze reagiert'},
#  {'start': 815.88, 'text': 'weil der hat sie dann wieder bedeutende'},
#  {'start': 818.79, 'text': 'bessere optionen weil wenn man hinten'},
#  {'start': 821.1, 'text': 'sitzt und das auto fährt darf man sich'},
#  {'start': 824.55, 'text': 'auch etwas mehrere trinken so aber de'},
#  {'start': 828.33, 'text': 'facto ist das hier die zukunft und diese'},
#  {'start': 833.16, 'text': 'zukunft ist realität bis das jetzt doch'},
#  {'start': 835.68, 'text': 'natürlich global eingesetzt wird und'},
#  {'start': 838.11, 'text': "ausgerollt wird geht's aber es ziehen"},
#  {'start': 840.69, 'text': 'aber es ist nicht nur google daran dass'},
#  {'start': 842.58, 'text': 'zu das zu initialisieren es ist auch'},
#  {'start': 845.46, 'text': 'apple zum beispiel der ein oder andere'},
#  {'start': 848.37, 'text': 'firmen und dann haben wir diese'},
#  {'start': 850.5, 'text': 'intelligenten assistenten die in unseren'},
#  {'start': 853.11, 'text': 'alltag vordringen so ich weiß nicht ob'},
#  {'start': 855.75, 'text': 'ihn das schon aufgefallen ist aber wenn'},
#  {'start': 857.64, 'text': 'sie im googlemail eine mail bekommen ich'},
#  {'start': 860.25, 'text': 'habe das hier bekommen und da werde ich'},
#  {'start': 862.77, 'text': 'für ein meeting angefragt und google'},
#  {'start': 865.38, 'text': 'macht vorgefertigte antworten also das'},
#  {'start': 869.46, 'text': 'heißt google analysiert den text und'},
#  {'start': 872.88, 'text': 'sagt ja ich kann sagen ich sei ein wort'},
#  {'start': 875.52, 'text': 'der da ist eigentlich recht interessant'},
#  {'start': 878.96, 'text': 'weil er besteht den text'},
#  {'start': 882.57, 'text': 'es kann auch nicht sein ich weiß es'},
#  {'start': 885.0, 'text': 'nicht die künstliche intelligenz'},
#  {'start': 886.17, 'text': 'versteht den text und sie merkt dass ich'},
#  {'start': 889.41, 'text': 'ein meeting request habe aber ohne'},
#  {'start': 892.77, 'text': 'zeitpunkt und die maschine schlägt mir'},
#  {'start': 896.79, 'text': 'jetzt schon die richtige antwort vor'},
#  {'start': 899.91, 'text': 'das ist realität heute dann die'},
#  {'start': 904.8, 'text': 'natürliche die natürliche art wie wir'},
#  {'start': 908.4, 'text': 'miteinander kommunizieren ist nicht wie'},
#  {'start': 910.56, 'text': 'erwartet ist nicht wir sms sollen ist'},
#  {'start': 913.47, 'text': 'gesprochen wie steht die heute'},
#  {'start': 915.93, 'text': 'vorliegenden ich spreche zu ihnen'},
#  {'start': 917.58, 'text': 'und das machen die menschen schon'},
#  {'start': 919.65, 'text': 'millionen so die schrift wurde etwas'},
#  {'start': 922.35, 'text': 'später erfunden und auch dinge'},
#  {'start': 923.97, 'text': 'festzuhalten um das wissen weiter zu'},
#  {'start': 926.28, 'text': 'geben aber die natürlichste von allen'},
#  {'start': 928.17, 'text': 'orten ist die kolonisation und in die'},
#  {'start': 931.05, 'text': 'richtung geht es klassische web seiten'},
#  {'start': 933.84, 'text': 'haben unser sicher auch ausgedient weil'},
#  {'start': 936.93, 'text': 'wir nicht sprechen können und etwas'},
#  {'start': 938.82, 'text': 'erfahren kann dann ist das viel'},
#  {'start': 942.06, 'text': 'spannender und da ist die jackpot das'},
#  {'start': 945.39, 'text': 'sind alles künstliche intelligenzen die'},
#  {'start': 947.97, 'text': 'mir helfen'},
#  {'start': 948.76, 'text': 'eine konversation zu führen ich zeige'},
#  {'start': 952.09, 'text': 'eine demo die demos in leiterin immerhin'},
#  {'start': 954.52, 'text': 'englisch aber man sieht hier wie ich ein'},
#  {'start': 957.79, 'text': 'flug nicht ich sondern der einflug sucht'},
#  {'start': 960.73, 'text': 'und die maschine antwortet darauf'},
#  {'start': 965.54, 'text': '[Musik]'},
#  {'start': 977.48, 'text': 'so'},
#  {'start': 980.98, 'text': 'die antworten werden auf die künstliche'},
#  {'start': 983.079, 'text': 'intelligenz generiert und es werden auch'},
#  {'start': 986.019, 'text': 'gleich angebot der 1'},
#  {'start': 989.03, 'text': 'geschrieben und ich kann natürlich auch'},
#  {'start': 991.49, 'text': 'krieg wenn nicht aus den augen weg will'},
#  {'start': 994.01, 'text': 'oder es kann was schreiben aber die'},
#  {'start': 996.08, 'text': 'maschine interpretiert text und bild'},
#  {'start': 998.78, 'text': 'zitiert wo ist und sie interpretiert'},
#  {'start': 1001.45, 'text': 'kriegst das heißt ich bin ich kann fast'},
#  {'start': 1004.45, 'text': 'schon natürliche konversationen führen'},
#  {'start': 1006.79, 'text': 'wenn ich das mag sie verliert auch den'},
#  {'start': 1010.93, 'text': 'kontext nicht also ich muss nicht alles'},
#  {'start': 1012.88, 'text': 'wiederholen und das ist schon eine'},
#  {'start': 1014.71, 'text': 'extreme leistung rechenleistung ich'},
#  {'start': 1018.58, 'text': 'mache zweiter google home heute auch'},
#  {'start': 1021.55, 'text': 'haben wir zu hause wir haben das im büro'},
#  {'start': 1024.67, 'text': 'das ist fantastisch mit dem kommen'},
#  {'start': 1027.34, 'text': 'sprechen da gibt einmal antworten'},
#  {'start': 1033.63, 'text': 'kammermusik'},
#  {'start': 1042.2, 'text': '[Musik]'},
#  {'start': 1064.15, 'text': '[Musik]'},
#  {'start': 1078.99, 'text': '[Musik]'},
#  {'start': 1083.25, 'text': 'das ist nicht gestellt das casting heute'},
#  {'start': 1086.32, 'text': 'wirklich und jetzt ist die frage was ist'},
#  {'start': 1089.53, 'text': 'in zwölf monaten was kann dieser'},
#  {'start': 1091.57, 'text': 'assistent in zwölf monaten'},
#  {'start': 1094.26, 'text': 'ich habe zum beispiel ein büro'},
#  {'start': 1097.12, 'text': 'assistenten der macht für dich termine'},
#  {'start': 1100.84, 'text': 'ob sie heißt es gibt auch eine männliche'},
#  {'start': 1103.51, 'text': 'version ich weiß nicht wieder wie der'},
#  {'start': 1105.31, 'text': 'bdr ist aber der macht die macht für'},
#  {'start': 1110.32, 'text': 'mich termine ab ich kann sagen hey mach'},
#  {'start': 1112.75, 'text': 'mit dem und dem ein termin oder lentge'},
#  {'start': 1114.97, 'text': 'und dann macht sie das bis der termin'},
#  {'start': 1116.65, 'text': 'steht und das ist extrem hilfreich'},
#  {'start': 1119.62, 'text': 'kostet 20 dollar im monat aber ich muss'},
#  {'start': 1123.19, 'text': 'mich nicht kümmern und sie kommt erst'},
#  {'start': 1124.51, 'text': 'wieder zurück wenn sie den termin hat'},
#  {'start': 1126.66, 'text': 'mit adress frage et cetera und ich'},
#  {'start': 1129.52, 'text': 'integriere nicht aber die andere seite'},
#  {'start': 1131.4, 'text': 'integriert permanent mit der künstlichen'},
#  {'start': 1133.69, 'text': 'intelligenz es wirklich cool ist x.de'},
#  {'start': 1136.17, 'text': 'kommen ausprobieren aber wo steht ihr'},
#  {'start': 1138.58, 'text': 'heute in zwölf monaten'},
#  {'start': 1141.87, 'text': 'das ist ich das ist auch nicht gestellt'},
#  {'start': 1149.69, 'text': '[Musik]'},
#  {'start': 1156.41, 'text': '[Musik]'},
#  {'start': 1167.45, 'text': '[Musik]'},
#  {'start': 1183.09, 'text': 'also auch da also rechts ist der'},
#  {'start': 1186.299, 'text': 'wichtigste horse alone lebens ist die'},
#  {'start': 1190.33, 'text': 'assistentin der ich sagen kann sie so'},
#  {'start': 1192.76, 'text': 'einen termin ausmachen und sie ruft und'},
#  {'start': 1194.89, 'text': 'die rechts merkt nicht dass sie mit'},
#  {'start': 1197.35, 'text': 'einem roboter spricht er mit der'},
#  {'start': 1199.929, 'text': 'künstlichen intelligenz und das ist'},
#  {'start': 1202.27, 'text': 'schon cool also wenn ich denke dass es'},
#  {'start': 1204.58, 'text': 'mich wirklich nicht so erfreut wenn ich'},
#  {'start': 1206.649, 'text': 'im restaurant noch einen platz fragen'},
#  {'start': 1208.539, 'text': 'muss und das ist einfach anstrengend und'},
#  {'start': 1211.39, 'text': 'ich meine sorgen kann ok google mail'},
#  {'start': 1215.59, 'text': "station vor nine o'clock dann ist das"},
#  {'start': 1218.89, 'text': 'schon ein fach also diese standort'},
#  {'start': 1221.26, 'text': 'sachen die uns eigentlich nur'},
#  {'start': 1222.88, 'text': 'beschäftigen aber nicht beschäftigen'},
#  {'start': 1224.47, 'text': 'müssen die haben wir die können wir sehr'},
#  {'start': 1227.919, 'text': 'einfach diesen assistenten abgeben so'},
#  {'start': 1230.59, 'text': 'wie stehen wir dann in der robotik'},
#  {'start': 1232.919, 'text': 'das war vor zwei jahren boston dynamics'},
#  {'start': 1238.649, 'text': 'in der zwischenzeit kein google'},
#  {'start': 1241.12, 'text': 'unternehmen mehr aber der ist autonom'},
#  {'start': 1244.84, 'text': 'das heißt er erkennt seine umgebung der'},
#  {'start': 1247.84, 'text': 'lok ein bisschen spazieren'},
#  {'start': 1250.77, 'text': 'der läuft noch den wald da braucht er'},
#  {'start': 1253.96, 'text': 'auch frische luft der hat das auch'},
#  {'start': 1255.88, 'text': 'gemerkt aber das ist ein bisschen'},
#  {'start': 1262.419, 'text': 'besoffen oder der torhüter manchmal rom'},
#  {'start': 1266.47, 'text': 'und ist ein bisschen unsicher'},
#  {'start': 1270.029, 'text': 'aber wenn man weiß wie viel hirn'},
#  {'start': 1273.85, 'text': 'kapazität wir brauchen um stehen und uns'},
#  {'start': 1277.929, 'text': 'ausbauen'},
#  {'start': 1278.759, 'text': 'die iren zu können dann ist das ein'},
#  {'start': 1282.179, 'text': 'meisterwerk der rechenleistung aber er'},
#  {'start': 1288.779, 'text': 'reagiert darauf also das ist wirklich'},
#  {'start': 1290.94, 'text': 'also man kann ihnen auch immer niemand'},
#  {'start': 1292.499, 'text': 'hat zum spazieren kommt er mit oder das'},
#  {'start': 1294.809, 'text': 'ist doch dann was wir auch haben und'},
#  {'start': 1300.179, 'text': 'oder wenn wir die heutigen roboter'},
#  {'start': 1302.279, 'text': 'anschauen bei so industrie straßen da'},
#  {'start': 1304.769, 'text': 'machen die etwas'},
#  {'start': 1305.94, 'text': 'die sind programmiert für'},
#  {'start': 1307.699, 'text': 'gleichbleibende arbeiten und der macht'},
#  {'start': 1314.579, 'text': 'das eigentlich schon ganz gut er ist'},
#  {'start': 1316.619, 'text': 'auch sehr pflichtbewusst als ich eine'},
#  {'start': 1318.509, 'text': 'kiste um so und das ist jetzt auch sehr'},
#  {'start': 1327.319, 'text': 'interessant weil der hatten auftrag zu'},
#  {'start': 1331.739, 'text': 'erfüllen also vor einer stunde hatten'},
#  {'start': 1336.479, 'text': 'purples haben wir vor einer stunde'},
#  {'start': 1338.159, 'text': 'gelernt'},
#  {'start': 1339.179, 'text': 'er will diese kiste will der wecker'},
#  {'start': 1341.819, 'text': 'kriegen'},
#  {'start': 1342.589, 'text': 'der tut ihm auch schon fast leid und man'},
#  {'start': 1348.749, 'text': 'hat auch immer irgendwie das gefühl der'},
#  {'start': 1350.969, 'text': 'rostet ist am walther aus und und so'},
#  {'start': 1358.169, 'text': 'zart dass eine kiste wieder'},
#  {'start': 1359.999, 'text': 'aber das ist jetzt ganz fies aber auch'},
#  {'start': 1366.449, 'text': 'das ist eine meisterleistung der steht'},
#  {'start': 1368.729, 'text': 'wieder auf'},
#  {'start': 1369.859, 'text': 'und er muss sich orientieren aber wir'},
#  {'start': 1372.449, 'text': 'liegt wie er wieder hochkommt und auf'},
#  {'start': 1374.969, 'text': 'zwei beinen zu stehen ist dann doch sehr'},
#  {'start': 1376.889, 'text': 'gut so vor einem jahr'},
#  {'start': 1381.589, 'text': 'das ist immer noch der gleiche aber der'},
#  {'start': 1384.269, 'text': 'springt jetzt schon rom und damit müsse'},
#  {'start': 1387.479, 'text': 'schauen wie schnell die entwicklung ist'},
#  {'start': 1389.489, 'text': 'das ist wirklich extrem'},
#  {'start': 1393.409, 'text': 'er kann unterschiedliche und ich bin'},
#  {'start': 1397.709, 'text': 'sicher es gibt eine olympische disziplin'},
#  {'start': 1402.379, 'text': 'und jetzt vor acht monaten die zieht'},
#  {'start': 1406.859, 'text': 'schon nicht mehr so besoffen auto also'},
#  {'start': 1409.889, 'text': 'der macht der relativ locker springt da'},
#  {'start': 1413.899, 'text': 'ja auch zum joggen ist das cool wenn ich'},
#  {'start': 1416.549, 'text': 'nicht mal eine zogen geben muss das'},
#  {'start': 1418.289, 'text': 'nicht aussuchen würde das sieht man ja'},
#  {'start': 1420.029, 'text': 'aber und auf unterschiedlichen gelände'},
#  {'start': 1425.129, 'text': 'so was macht ihr da noch dass sie auch'},
#  {'start': 1427.169, 'text': 'etwas auch wenn sie sehen wie schnell'},
#  {'start': 1430.619, 'text': 'das geht dann ist das wirklich ein'},
#  {'start': 1433.289, 'text': 'bisschen erschreckend die entwicklung'},
#  {'start': 1435.629, 'text': 'die in anderthalb jahre und stattfindet'},
#  {'start': 1437.789, 'text': 'mit künstlichen intelligenzen aber das'},
#  {'start': 1440.389, 'text': 'kann nur mit künstlicher intelligenz'},
#  {'start': 1442.979, 'text': 'gemacht werden das kann man nicht mit'},
#  {'start': 1444.989, 'text': 'programmieren machen und sagen als auch'},
#  {'start': 1448.889, 'text': 'das sehr coole anwendung'},
#  {'start': 1451.019, 'text': 'das kennen sie das haben sie das haupt'},
#  {'start': 1453.57, 'text': 'kennen sie haben was da einfach cool ist'},
#  {'start': 1457.07, 'text': 'du kannst aus hinhalten und das'},
#  {'start': 1460.529, 'text': 'übersetzt ist direkt sogar in der'},
#  {'start': 1462.419, 'text': 'typografie des schildes eine empfehlung'},
#  {'start': 1466.349, 'text': 'die popkomm translator stimmung von'},
#  {'start': 1469.739, 'text': 'google da ist viel besser als google ich'},
#  {'start': 1473.309, 'text': 'bin sonst wirklich großer fan von google'},
#  {'start': 1475.529, 'text': 'aber da können sie auch'},
#  {'start': 1476.789, 'text': 'wissenschaftliche texte übersetzen'},
#  {'start': 1480.57, 'text': 'lassen der arbeitet hervorragend und der'},
#  {'start': 1483.149, 'text': 'wir täglich besser dann übernehmen'},
#  {'start': 1489.269, 'text': 'künstliche intelligenzen die welt also'},
#  {'start': 1492.359, 'text': 'wenn sie es nicht schon gemacht haben'},
#  {'start': 1493.979, 'text': 'irgendwann wahrscheinlich schon und zwar'},
#  {'start': 1499.129, 'text': 'es werden viele prozesse digitalisierte'},
#  {'start': 1502.469, 'text': 'ich vorher gesagt habe so dieses'},
#  {'start': 1504.57, 'text': 'standardprozesse irgendwo anrufen'},
#  {'start': 1506.899, 'text': 'reservation zu machen e mails'},
#  {'start': 1509.129, 'text': 'beantworten briefe ablegen'},
#  {'start': 1511.379, 'text': 'all diese repetitiven sachen die'},
#  {'start': 1514.2, 'text': 'eigentlich gar nicht mehr so machen will'},
#  {'start': 1516.7, 'text': 'wir haben durch künstliche intelligenzen'},
#  {'start': 1519.22, 'text': 'ersetzt vor allem auch im office bereich'},
#  {'start': 1523.05, 'text': 'aber auch bei kosten mitarbeiterinnen'},
#  {'start': 1526.3, 'text': "bei mcdonald's medizin medizin übrigens"},
#  {'start': 1530.83, 'text': 'ein sehr wird sehr viel profitieren von'},
#  {'start': 1533.86, 'text': 'künstlicher intelligenz für künstliche'},
#  {'start': 1535.78, 'text': 'intelligenz kann sehr viele daten'},
#  {'start': 1538.11, 'text': 'auswerten und analysieren'},
#  {'start': 1543.25, 'text': 'viel mehr als dass das ein einzelner'},
#  {'start': 1545.5, 'text': 'arzt könnte wir haben auch natürliche'},
#  {'start': 1549.22, 'text': 'taxi vor fabrikarbeiter aber also nichts'},
#  {'start': 1553.96, 'text': 'nichts gegen anwälte das ist jetzt ein'},
#  {'start': 1556.09, 'text': 'beliebiges example aber es geht auch'},
#  {'start': 1563.05, 'text': 'darum dass wir zum teil berufe die die'},
#  {'start': 1568.14, 'text': 'halter akademischer natur sind durch die'},
#  {'start': 1571.21, 'text': 'maschinen jetzt verdrängt werden'},
#  {'start': 1573.27, 'text': 'die aufgabe war simpel anwälte'},
#  {'start': 1576.46, 'text': 'analysieren ein die er ist die 30'},
#  {'start': 1579.75, 'text': 'rechtliche probleme versteckt hatten die'},
#  {'start': 1583.0, 'text': 'corrie benötigte 26 sekunden mit einer'},
#  {'start': 1586.57, 'text': 'genauigkeit von 94 prozent'},
#  {'start': 1588.88, 'text': 'die online alte benötigen 92 minuten mit'},
#  {'start': 1592.12, 'text': 'einer genauigkeit von 85 prozent und das'},
#  {'start': 1594.76, 'text': 'ist die frage wo geht das hin'},
#  {'start': 1596.74, 'text': 'im ersten video haben wir gesehen dass'},
#  {'start': 1599.05, 'text': 'die maschine entscheidungen fällt also'},
#  {'start': 1605.1, 'text': 'mit liquidieren das wollen wir natürlich'},
#  {'start': 1608.11, 'text': 'nicht auch wenn die maschine genau ist'},
#  {'start': 1610.63, 'text': 'bei der analyse analyse von'},
#  {'start': 1612.54, 'text': 'geheimhaltungs verträgen ist und auch'},
#  {'start': 1614.5, 'text': 'die frage wird es irgendwann nicht'},
#  {'start': 1616.54, 'text': 'besser sein wenn wir eine ausrichter'},
#  {'start': 1620.08, 'text': 'haben damit sich konsistent dass ich in'},
#  {'start': 1624.22, 'text': 'ihren urteilen bewegen dann das andere'},
#  {'start': 1629.32, 'text': 'problem ist wir haben also das ist nicht'},
#  {'start': 1632.59, 'text': 'von uns das ist vom world economic forum'},
#  {'start': 1635.37, 'text': '2016 haben sie behauptet das 5 1'},
#  {'start': 1639.25, 'text': 'millionen jobs verloren gehen'},
#  {'start': 1642.09, 'text': 'wegen artificial intelligence 2'},
#  {'start': 1646.89, 'text': 'millionen jobs würden neu geschaffen'},
#  {'start': 1648.39, 'text': 'also zum schluss dass die etwas übrig'},
#  {'start': 1651.059, 'text': 'breite ich finde das etwas pessimistisch'},
#  {'start': 1654.539, 'text': 'ich sehe diesen trend noch nicht das'},
#  {'start': 1656.909, 'text': 'wird sich schon noch etwas hinziehen'},
#  {'start': 1660.89, 'text': 'aber wir sind der überzeugung dass die'},
#  {'start': 1663.779, 'text': 'menschheit sich in den nächsten 20'},
#  {'start': 1666.36, 'text': 'jahren stark verändern werden mal sehen'},
#  {'start': 1668.82, 'text': 'auch diese tendenzen wie sich die jugend'},
#  {'start': 1671.37, 'text': 'heute eigentlich auch schon anders'},
#  {'start': 1674.179, 'text': 'positioniert einfaches leben suchen und'},
#  {'start': 1681.36, 'text': 'die maschinen helfen da natürlich schon'},
#  {'start': 1685.289, 'text': 'mit und was wir beobachten ist die'},
#  {'start': 1687.84, 'text': 'elektronische welt ist mit der'},
#  {'start': 1690.72, 'text': 'biologischen noch nicht verknüpft'},
#  {'start': 1693.33, 'text': 'außer mit der stimme über über physik'},
#  {'start': 1696.539, 'text': 'aber wenn ihr diese verschmelzung'},
#  {'start': 1698.48, 'text': 'hinkriegen dass wir unsere hier'},
#  {'start': 1701.88, 'text': 'leistungen mit künstlicher intelligenz'},
#  {'start': 1704.159, 'text': 'bauern können also wie ich ein auto'},
#  {'start': 1706.649, 'text': 'tuner kann ich das war ja eigentlich'},
#  {'start': 1710.58, 'text': 'auch mit meinem hermachen und alle haben'},
#  {'start': 1714.09, 'text': 'das gleiche wissen und alle auf den'},
#  {'start': 1716.13, 'text': 'zugang zum gleichen wissen dann wird das'},
#  {'start': 1718.2, 'text': 'dann auch sehr spannend dann kann ich'},
#  {'start': 1719.7, 'text': 'dann auch meine jungs studium mit einer'},
#  {'start': 1721.44, 'text': 'auf sekunden absolvieren und dann ist'},
#  {'start': 1724.02, 'text': 'die frage wie ich das dann wieder regel'},
#  {'start': 1726.049, 'text': 'wer kommt welchen zugang zu welchen'},
#  {'start': 1728.909, 'text': 'informationen und das regel männer in'},
#  {'start': 1731.73, 'text': 'der regel über gehälter so dann auch was'},
#  {'start': 1736.02, 'text': 'sie oft gefragt können künstliche'},
#  {'start': 1737.789, 'text': 'intelligenzen gefühle entwickeln sind'},
#  {'start': 1741.69, 'text': 'sie kreativ wir haben für einen fashion'},
#  {'start': 1746.46, 'text': 'label haben wir stoffmuster entwickelt'},
#  {'start': 1750.33, 'text': 'mit künstlicher intelligenz und die'},
#  {'start': 1753.419, 'text': 'waren viel komplexer diese stoffmuster'},
#  {'start': 1756.24, 'text': 'aus dass irgendein dieser 1 3 hätte'},
#  {'start': 1759.419, 'text': 'machen können und das war auch ein'},
#  {'start': 1761.7, 'text': 'erfolg für uns ein test dass die'},
#  {'start': 1763.5, 'text': 'maschine auch hier'},
#  {'start': 1767.09, 'text': 'kreativität adaptieren kann aber die'},
#  {'start': 1770.96, 'text': 'frau geht der gefühle ist ziemlich'},
#  {'start': 1774.26, 'text': 'wichtig wer hat im film ex machina'},
#  {'start': 1778.01, 'text': 'gesehen'},
#  {'start': 1782.65, 'text': 'das ist sie'},
#  {'start': 1791.85, 'text': 'hi'},
#  {'start': 1794.7, 'text': 'ok'},
#  {'start': 1798.61, 'text': 'ok'},
#  {'start': 1807.99, 'text': 'ein'},
#  {'start': 1809.75, 'text': 'so man sieht ganz deutlich das ist keine'},
#  {'start': 1814.29, 'text': 'frau das ist ein android ein roboter und'},
#  {'start': 1820.53, 'text': 'im film geht es darum bringt sie ihn'},
#  {'start': 1822.69, 'text': 'dazu dass er sie befreit'},
#  {'start': 1825.77, 'text': 'schauen sie den film weil es ist ja auch'},
#  {'start': 1830.1, 'text': 'beim filmen so was wir mit fühlen dh man'},
#  {'start': 1833.97, 'text': 'kann menschliche emotionen kann man so'},
#  {'start': 1840.44, 'text': 'kommen erzeugen wie alle wissen dass im'},
#  {'start': 1843.51, 'text': 'kino der film nicht echt ist'},
#  {'start': 1845.4, 'text': 'wir trauern mit wenn jemand stirbt wir'},
#  {'start': 1847.95, 'text': 'finden es spannend wenn irgendetwas'},
#  {'start': 1849.84, 'text': 'passiert wenn jemand hingerichtet wird'},
#  {'start': 1852.27, 'text': 'dann trauen wie also wir haben all diese'},
#  {'start': 1854.31, 'text': 'emotionen obwohl wir wissen das ist ein'},
#  {'start': 1856.74, 'text': 'film machine können wahrscheinlich keine'},
#  {'start': 1860.82, 'text': 'gefühle erleben aber sie können muster'},
#  {'start': 1862.83, 'text': 'erkennen und sie können interpretieren'},
#  {'start': 1865.44, 'text': 'und da mehr menschen auf muster rein'},
#  {'start': 1867.51, 'text': 'wollen werden sie uns auch'},
#  {'start': 1870.65, 'text': 'dementsprechend suggerieren können dass'},
#  {'start': 1873.96, 'text': 'sie emotionen fühlen'},
#  {'start': 1876.71, 'text': 'ich habe den vortrag bewusst etwas'},
#  {'start': 1879.35, 'text': 'düster gestaltet es gibt auch eine'},
#  {'start': 1881.82, 'text': 'deutlich also nicht aus die ddr'},
#  {'start': 1884.78, 'text': 'deprimiert nach hause gehen es gibt da'},
#  {'start': 1887.01, 'text': 'auch noch eine bessere zukunft aber'},
#  {'start': 1890.97, 'text': 'maschinen ist ein fakt treten in unser'},
#  {'start': 1894.42, 'text': 'leben ein'},
#  {'start': 1895.29, 'text': 'wir nutzen sie schon wir haben sie auf'},
#  {'start': 1898.17, 'text': 'dem telefon wir haben sie im computer'},
#  {'start': 1900.57, 'text': 'wir haben sie in software'},
#  {'start': 1902.31, 'text': 'wir haben sie praktisch überall in'},
#  {'start': 1904.89, 'text': 'unseren alltag schon rein gelassen und'},
#  {'start': 1907.8, 'text': 'google arbeitet am roten knopf weil wenn'},
#  {'start': 1910.38, 'text': 'die maschine da wirklich mal'},
#  {'start': 1913.01, 'text': 'rausgelassen ist sollte man sie wieder'},
#  {'start': 1915.78, 'text': 'abschalten können pakets leid noch keine'},
#  {'start': 1919.02, 'text': 'lösung dazu um den abschluss von meinem'},
#  {'start': 1923.43, 'text': 'vortrag mit etwas ganz positiven zu'},
#  {'start': 1926.91, 'text': 'wenden'},
#  {'start': 1927.72, 'text': 'dass das letztes leid und ich kann nur'},
#  {'start': 1929.94, 'text': 'sagen ja möge die e ii mit ihnen sein'},
#  {'start': 1933.06, 'text': 'und ich hoffe es kommen'},
#  {'start': 1935.11, 'text': 'dann'},
#  {'start': 1942.33, 'text': 'vielen herzlichen dank moment nicht'},
#  {'start': 1944.71, 'text': 'weglaufen sie kriegen noch ein geschenk'},
#  {'start': 1946.15, 'text': 'ist es worauf ein wasserglas nadine'},
#  {'start': 1952.77, 'text': 'stark ist eine künstliche aus dem stand'},
#  {'start': 1959.8, 'text': 'zu ich das schwer so das sind ganz tolle'},
#  {'start': 1972.43, 'text': 'weine die braucht er nicht mal mensch'},
#  {'start': 1976.54, 'text': 'würde ich ja wie holzmann reinigen und'},
#  {'start': 1979.87, 'text': 'ein selbstgemachter körper vielen dank'},
#  {'start': 1982.39, 'text': 'sie dürfen uns jetzt ein bisschen halten'},
#  {'start': 1984.37, 'text': 'weil ich habe trotzdem noch fragen'},
#  {'start': 1987.99, 'text': 'beziehen bio ist die glocken also ich'},
#  {'start': 1993.37, 'text': 'möchte sie nachher klarheit der griffe'},
#  {'start': 1995.53, 'text': 'der pause mit dem vielleicht mit'},
#  {'start': 1996.94, 'text': 'schwarzem sie bitten ein bisschen davon'},
#  {'start': 1999.96, 'text': 'haben sie den film music gesehen und da'},
#  {'start': 2003.84, 'text': 'geht es ja darum scarlett johansson'},
#  {'start': 2005.75, 'text': 'bekommt eine droge gespitzt und dann'},
#  {'start': 2009.33, 'text': 'kann sie mir aus 16 prozent ihres'},
#  {'start': 2011.67, 'text': 'gehirns nutzen und es steigt so 20'},
#  {'start': 2013.95, 'text': 'prozent wieder delfine 30 prozent 40'},
#  {'start': 2016.71, 'text': 'sieht sie immer mehr als andere leute'},
#  {'start': 2018.6, 'text': 'hat mehr kräfte sie haben vorhin gesagt'},
#  {'start': 2021.33, 'text': 'dass die rechenleistung so sehr viel'},
#  {'start': 2023.76, 'text': 'größer ist aber warum arbeiten wir nicht'},
#  {'start': 2026.7, 'text': 'daran dass wir unsere gehirnleistung'},
#  {'start': 2027.9, 'text': 'erhöhen ja das ist der zweite schritt'},
#  {'start': 2030.24, 'text': 'weil wir die gehirnleistung irgendwann'},
#  {'start': 2032.82, 'text': 'mit diesen neuen technologien verbessern'},
#  {'start': 2035.82, 'text': 'werden also wie wir das auto mit dem'},
#  {'start': 2037.5, 'text': 'motor tunen'},
#  {'start': 2038.55, 'text': 'wir haben wir diese rechenleistung'},
#  {'start': 2039.99, 'text': 'nutzen das auch unsere hirne besser'},
#  {'start': 2041.91, 'text': 'funktionieren und die maschine diakonat'},
#  {'start': 2046.08, 'text': 'global daten verarbeiten und die wayss'},
#  {'start': 2048.36, 'text': 'verbessern wie die zugang zu diesen'},
#  {'start': 2050.16, 'text': 'informationen bekommen dann werden wir'},
#  {'start': 2052.86, 'text': 'auf unserer hier und leistung'},
#  {'start': 2054.12, 'text': 'dementsprechend verbessert haben aber'},
#  {'start': 2057.81, 'text': 'natürlich nicht in dem ausmaß sie also'},
#  {'start': 2060.66, 'text': 'ich bin schon beeindruckt bei boston'},
#  {'start': 2062.34, 'text': 'dynamics der hat jetzt ungefähr wie viel'},
#  {'start': 2064.2, 'text': 'weniger als zwei jahren richtig zu'},
#  {'start': 2066.12, 'text': 'laufen wenn man bedenkt dass ein kind'},
#  {'start': 2067.86, 'text': 'drei jahre braucht um überhaupt und ich'},
#  {'start': 2071.37, 'text': "hab's übliche studieren"},
#  {'start': 2072.94, 'text': 'um überhaupt zu lernen wie man einen'},
#  {'start': 2075.8, 'text': 'löffel zum mund führt er hat es sind'},
#  {'start': 2079.82, 'text': 'unglaubliche dass das wissen viele nicht'},
#  {'start': 2081.619, 'text': 'aber das ist eine unglaubliche'},
#  {'start': 2083.149, 'text': 'gehirnleistung und wenn der roboter das'},
#  {'start': 2085.82, 'text': 'ja eigentlich noch schneller lernt als'},
#  {'start': 2087.56, 'text': 'der mensch das macht mir schon ein'},
#  {'start': 2088.7, 'text': 'bisschen angst und seine kurve geht so'},
#  {'start': 2091.04, 'text': 'ich hätte auch andere videos gehabt aber'},
#  {'start': 2093.8, 'text': 'ich wollte in den tag nicht ganz'},
#  {'start': 2095.09, 'text': 'verderben'},
#  {'start': 2096.73, 'text': 'das wichtigste was das größte problem'},
#  {'start': 2099.74, 'text': 'das wir noch haben in der robotik ist'},
#  {'start': 2101.96, 'text': 'die energieversorgung oder es ist jetzt'},
#  {'start': 2103.88, 'text': 'sehr trikot in der mit dem rasenmäher'},
#  {'start': 2105.86, 'text': 'motor auf dem rücken trend sondern das'},
#  {'start': 2108.71, 'text': 'muss elektrisch sein dass man sie auch'},
#  {'start': 2110.3, 'text': 'modern sein aber mit den mit dem mit der'},
#  {'start': 2113.24, 'text': 'energieversorgung haben wir noch'},
#  {'start': 2114.92, 'text': 'probleme aber es ist natürlich danach so'},
#  {'start': 2117.11, 'text': 'wenn die energieversorgung gelöst ist so'},
#  {'start': 2119.36, 'text': 'ein roboter zwei drei wochen autonom'},
#  {'start': 2122.27, 'text': 'überlebt dann ja die werden ja autoren'},
#  {'start': 2128.3, 'text': 'dann in kriegseinsätze geführt werden'},
#  {'start': 2132.04, 'text': 'jetzt habe ich nur noch eine persönliche'},
#  {'start': 2133.91, 'text': 'frage alexa oder hey google goog o wie'},
#  {'start': 2137.48, 'text': 'so viel besser so weil sie also'},
#  {'start': 2141.71, 'text': 'google.com kontextuellen fragen'},
#  {'start': 2145.28, 'text': 'beantworten und google kann auch mehrere'},
#  {'start': 2148.99, 'text': 'auch ein hinterer und auch während'},
#  {'start': 2152.03, 'text': 'kriegt man das in der schweiz weil ich'},
#  {'start': 2155.54, 'text': 'habe versucht alexa zu bestellen das'},
#  {'start': 2157.07, 'text': 'geht eben nicht über amazon ist nur okay'},
#  {'start': 2166.13, 'text': 'gut dann melde ich mich gleich bei ihnen'},
#  {'start': 2168.29, 'text': 'recht geben vielen dank'},
#  {'start': 2173.41, 'text': '[Applaus]'}]

# %% [markdown]
# # Exploratory Data Analysis

# %%
from collections import Counter

import matplotlib.pyplot as plt
import nltk as nlp
import numpy as np
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from wordcloud import STOPWORDS, WordCloud

plt.style.use('seaborn-notebook')
# %matplotlib inline

# %%
def plot_number_words(raw_text: str):
    n_words = len(raw_text.split())
    n_unique_words = len(set(raw_text.split()))
    print('Number of words: {}\nNumber of unique words: {}'.format(
        n_words, n_unique_words))
    height = [n_words, n_unique_words]
    bars = ("Words", "Unique words")
    y_pos = np.arange(len(bars))
    plt.bar(y_pos, height, color=['black', 'orange'])
    plt.xticks(y_pos, bars)
    plt.plot()

plot_number_words(raw_text)
# Out:
# Number of words: 3889
# Number of unique words: 1133

# %%
word_list = raw_text.split()
counts = dict(Counter(word_list).most_common(50))

labels, values = zip(*counts.items())
indSort = np.argsort(values)[::-1]
labels = np.array(labels)[indSort]
values = np.array(values)[indSort]
indexes = np.arange(len(labels))

cmap = plt.cm.get_cmap('jet')
colors = cmap(np.arange(cmap.N))[::-5]
plt.figure(figsize=(20, 10))
plt.bar(indexes, values, color=colors)
plt.xticks(indexes, labels, fontsize=13, rotation=90)
plt.title("Top 50 (Uncleaned) Word frequencies")
plt.plot()

# %% [markdown]
# ## Word clouds
#
# Before creating a word cloud, we want to remove stopwords and lemmatize the text corpus.

# %%
wordnet_lemmatizer = WordNetLemmatizer()
words = set(stopwords.words('german')) | set(stopwords.words('english'))
raw_text = ' '.join(wordnet_lemmatizer.lemmatize(word) for word in raw_text.split() if word not in words)

# %%
plt.figure(figsize=(24, 18))
plt.subplot(211)
wc = WordCloud(
    background_color="white",
    max_words=1000,
    stopwords=STOPWORDS,
    max_font_size=40)
wc.generate(raw_text)
plt.title(talk_title)
plt.imshow(wc.recolor(colormap='Dark2', random_state=6))
plt.axis('off');

# %% [markdown]
# # Subtitles summary
#
# Following approach implements TextRank: Bringing Order into Texts, Mihalcea et al. 2004

# %%
import networkx as nx
import numpy as np
import pandas as pd
from nltk.cluster.util import cosine_distance
from nltk.corpus import stopwords
from nltk.tokenize import sent_tokenize
from sklearn.metrics.pairwise import cosine_similarity


class ExtractiveSummary:
    """
    Graph-based ranking algorithm for extractive summaries,
    based on top of PageRank.
    """

    def __init__(self, raw_text: tuple, top_k: int=10):
        self.raw_text = raw_text
        self.top_k = top_k
        self._summary = ''

    def get_summary(self) -> str:
        """Creates an extractive summary based on input text corpus."""
        summarize_text = []
        clean_sentences, sentences = self.create_clean_sentences()
        sentence_vector = SentenceVector('glove.6B.100d.txt', clean_sentences)
        sim_mat = SimilarityMatrix(sentence_vector.vector, clean_sentences, len(sentences))
        nx_graph = nx.from_numpy_array(sim_mat.matrix)
        scores = nx.pagerank(nx_graph)
        ranked_sentences = sorted(
            ((scores[i], s) for i, s in enumerate(sentences)), reverse=True)
        for i in range(self.top_k):
            summarize_text.append(ranked_sentences[i][1])
        self._summary = ' '.join(summarize_text)
        return self._summary
        

    def create_clean_sentences(self):
        self.raw_text = (talk_title, self.raw_text)
        sentences = []
        for s in self.raw_text:
            sentences.append(sent_tokenize(s))

        sentences = [y for x in sentences for y in x]
        clean_sentences = pd.Series(sentences).str.replace("[^a-zA-Z]", " ")
        clean_sentences = [s.lower() for s in clean_sentences]
        stop_words = set(stopwords.words('english')) | set(
            stopwords.words('german'))

        def _filter_stopwords(sentence):
            sen_new = " ".join(
                [sen for sen in sentence if sen not in stop_words])
            return sen_new

        clean_sentences = [
            _filter_stopwords(r.split()) for r in clean_sentences
        ]
        return clean_sentences, sentences
    
    def __repr__(self):
        return self._summary


class SimilarityMatrix:
    def __init__(self, sentence_vector, clean_sentences, sentence_lenght):
        self.sentence_vector = sentence_vector
        self.clean_sentences = clean_sentences
        self.sentence_lenght = sentence_lenght
        
    @property
    def matrix(self):
        sim_mat = np.zeros([self.sentence_lenght, self.sentence_lenght])

        for i in range(self.sentence_lenght):
            for j in range(self.sentence_lenght):
                if i != j:
                    sim_mat[i][j] = cosine_similarity(
                        self.sentence_vector[i].reshape(1, 100),
                        self.sentence_vector[j].reshape(1, 100))[0, 0]
        return sim_mat


class SentenceVector:
    def __init__(self, filepath: str, clean_sentences: list):
        self.filepath = filepath
        self.clean_sentences = clean_sentences
        self._sentence_vectors = []

    @property
    def vector(self):
        word_embeddings = dict()
        with open(self.filepath, 'r', encoding='utf-8') as f:
            for line in f:
                values = line.split()
                word = values[0]
                coefs = np.asarray(values[1:], dtype='float32')
                word_embeddings[word] = coefs
        for i in self.clean_sentences:
            if len(i) != 0:
                v = sum([
                    word_embeddings.get(w, np.zeros((100, )))
                    for w in i.split()
                ]) / (len(i.split()) + 0.001)
            else:
                v = np.zeros((100, ))
            self._sentence_vectors.append(v)
        return self._sentence_vectors

# %% [markdown]
# Add artificial punctuation every nth sentence.

# %%
def synthetic_points(xml_struct, n):
    return ' '.join(
        [v['text'] + '.' * (i % n == 0) for i, v in enumerate(xml_struct)])

# %% [markdown]
# # Results

# %% [markdown]
# ## YouTube video

# %%
text = synthetic_points(xml_struct, 5)
extractive_summary = ExtractiveSummary(text)
summary = extractive_summary.get_summary()
print(summary)
# Out:
# und das ist die frage wo geht das hin im ersten video haben wir gesehen dass die maschine entscheidungen fällt. die entwicklung die in anderthalb jahre und stattfindet mit künstlichen intelligenzen. und was wir beobachten ist die elektronische welt ist mit der biologischen noch nicht verknüpft außer mit der stimme über über physik aber wenn ihr diese verschmelzung hinkriegen dass wir unsere hier leistungen mit künstlicher intelligenz bauern können. vor vier oder fünf tagen hat der papa das ist vom amerikanischen militär bekannt gegeben dass sie zwei milliarden investieren in die künstliche intelligenz. auch wenn wir da und geschichten wieder hören dass da ein autonomes fahrzeuge gecrasht ist. drei jahre braucht um überhaupt und ich hab's übliche studieren um überhaupt zu lernen wie man einen löffel zum mund führt er hat es sind unglaubliche dass das wissen viele nicht. und da mehr menschen auf muster rein wollen werden sie uns auch dementsprechend suggerieren können dass sie emotionen fühlen ich habe den vortrag bewusst etwas. und darauf sind wir natürlich auch stolz aber fangen wir sagen dass wir kommen in der wunderbaren welt der künstlichen intelligenz. aber das ist alles künstliche intelligenz und die künstliche intelligenz ist alles eine frage der rechenleistung und des speicherplatzes. dann trauen wie also wir haben all diese emotionen obwohl wir wissen das ist ein film machine können wahrscheinlich keine gefühle erleben aber sie können muster erkennen und sie können interpretieren.

# %% [markdown]
# ## Arbitrary Webpage

# %%
url = 'https://deep-impact.ch'
website_text = WebsiteText.get_text(url)
extractive_summary_website = ExtractiveSummary(website_text)
summary_website = extractive_summary_website.get_summary()
print(summary_website)
# Out:
# Deep Impact denken intensiv über die Probleme nach und bauen anschliessend die bestmögliche und effizienteste Lösung.
# Von der Idee zum Prototyp in nur 4 Tagen: Wir beschleunigen den Weg von der Idee zur Umsetzung und führen mit dem Design Sprint Framework schneller als je zuvor zur validierten Lösung.
# Einfache Lösungen für komplexe geschäftliche Herausforderungen.
# Wir designen, entwickeln und vermarkten disruptive Software und führen diese in weniger als 6 Monaten ein.
# Wir verfügen über umfangreiche Erfahrung im Erstellen und Betrieb von Plattformen für eine Vielzahl von Branchen.
# Lösungen für ungelöste Probleme finden.
# Es wird raschmöglichst online veröffentlicht, um das Feedback von Kunden einzuholen.
# Durch den Bau von Prototypen und das Testen Ihrer Ideen innerhalb von 2 Wochen, wird das Risiko für ein MVP zu bauen, deutlich reduziert.
# Verschiedene Experten von Auftraggeber und uns erarbeiten in kollaborativen Schritten die Lösung.
# So entwickeln wir Web Software, die realen Bedürfnisse der Kunden und Benutzer optimal abdeckt.
